# %% [markdown]
# ## Line Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
points = np.array([4, 7, 2, 10, 13])

# %%
plt.plot(points)
plt.show()

# %%
a2 = np.array([1, 2, 3, 4, 5, 6])
plt.plot(a2, linestyle='dotted')
plt.show()

# %%
a2 = np.array([1, 2, 3, 4, 5, 6])
plt.plot(a2, linestyle='dashed')
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
x = np.array(["X", "Y", "Z", "W"])
y = np.array([25, 30, 27, 22])

# %%
plt.bar(x, y)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
x1 = np.array([20, 15, 11, 7, 8, 10])
y1 = np.array([2, 7, 15, 8, 10, 12])

# %%
plt.scatter(x1, y1)
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
p = np.array([30, 20, 25, 20])
plt.pie(p)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e3452733e0>,
#   <matplotlib.patches.Wedge at 0x1e3453238c0>,
#   <matplotlib.patches.Wedge at 0x1e3452f03b0>,
#   <matplotlib.patches.Wedge at 0x1e34303ef00>],
#  [Text(0.6016430102375327, 0.9208831023709363, ''),
#   Text(-0.9674210876290679, 0.5235422038485451, ''),
#   Text(-0.6016430102375331, -0.9208831023709361, ''),
#   Text(0.868054557006695, -0.6756339882361682, '')])

# %% [markdown]
# ## Histogram

# %%
h1 = np.random.normal(170, 10, 250)

# %%
plt.hist(h1)
plt.show()
